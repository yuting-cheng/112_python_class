# %%
56+92
# Out:
# 148

# %%
56+92.0
# Out:
# 148.0

# %%
"我識字串"+50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 "我識字串"+50
#
# TypeError: can only concatenate str (not "int") to str

# %%
"我是字串" + "50"

# %%
(5+8, 90-10, 4*7 ,6/2, 7//2,7%3)

# %%
2+3*4

# %%
2 * (1+2)** 2-2 **2*2

# %%
"99"+ str(99) , int("99") +99

# %%
eval("2 * ( 1 + 2 ) ** 2 - 2 ** 2 * 2 ") ,eval("2 * (1 + 2) ** 2 - 2 ** 2 * 2")

# %%
#暫時儲存資料
#建立變數n
n = 99**99
n

# %%
print("abc")

# %%
n = 5
m = 10
mn = n+m
mn

# %%
n =5 
n = n + 10

n

# %%
n = 5
n += 10 #此用法與第38的 n = n+10結果相同，直接將n+10
n

# %%
n = 5
m = 10

print(f"n + m = {n+m}")

# %%
n = 5
m = 10
#{}內放變數,字串插補
print(f"{n}+{m}={n+m}") 
#上列用法為 print( str(n) + "+" + str(m) + "=" + str(n+m)) 之簡化

# %%
n = 5
m = 10
result = input (f"請輸入 {n} + {m} 的數值:")
